# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
from utils_3d import *
from ops_3d import *

# %%
# !python main_3d.py --dataset_dir /lustre4/2/managed_datasets/LIDC-IDRI/ --scratch_dir /scratch-shared/lidc-idri/
# Out:
# Copying files from /lustre4/2/managed_datasets/LIDC-IDRI/tfrecords_4x4x4 to  /scratch-shared/lidc-idri/tfrecords_4x4x4
# Done!
# 2019-09-03 14:54:26.405822: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-09-03 14:54:26.461421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla K40m major: 3 minor: 5 memoryClockRate(GHz): 0.745
# pciBusID: 0000:02:00.0
# 2019-09-03 14:54:26.462711: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 1 with properties:
# name: Tesla K40m major: 3 minor: 5 memoryClockRate(GHz): 0.745
# pciBusID: 0000:82:00.0
# 2019-09-03 14:54:26.463900: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-09-03 14:54:26.467013: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# ...
